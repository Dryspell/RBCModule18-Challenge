# %%
import pandas as pd
# !pip install sklearn
from sklearn.preprocessing import MinMaxScaler, LabelEncoder

# %matplotlib inline
# Out:
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
#   Preparing metadata (setup.py) ... done
# Collecting scikit-learn
#   Using cached scikit_learn-1.0.2-cp310-cp310-macosx_10_13_x86_64.whl (8.0 MB)
# Collecting scipy>=1.1.0
#   Downloading scipy-1.8.0-cp310-cp310-macosx_12_0_universal2.macosx_10_9_x86_64.whl (55.6 MB)
#      |████████████████████████████████| 55.6 MB 5.6 MB/s
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Collecting joblib>=0.11
#   Using cached joblib-1.1.0-py2.py3-none-any.whl (306 kB)
# Requirement already satisfied: numpy>=1.14.6 in /opt/miniconda3/envs/class_env/lib/python3.10/site-packages (from scikit-learn->sklearn) (1.22.1)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1310 sha256=5a925f38d01b42cecdfe07d1d1afd8b1d228b615ff92c5ad6d366321729de8da
#   Stored in directory: /Users/haaris/Library/Caches/pip/wheels/9b/13/01/6f3a7fd641f90e1f6c8c7cded057f3394f451f340371c68f3d
# Successfully built sklearn
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn, sklearn
# Successfully installed joblib-1.1.0 scikit-learn-1.0.2 scipy-1.8.0 sklearn-0.0 threadpoolctl-3.1.0

# %%
df = pd.read_csv('../Resources/marathon_results_2019.csv')
df.head()
# Out:
#   Bib               Name  Age M/F      City State Country Citizen Unnamed: 8  \
# 0   2  Cherono, Lawrence   30   M   Eldoret   NaN     KEN     NaN        NaN
# 1   6     Desisa, Lelisa   29   M      Ambo   NaN     ETH     NaN        NaN
# 2   7  Kipkemoi, Kenneth   34   M   Eldoret   NaN     KEN     NaN        NaN
# 3   8      Kandie, Felix   32   M      Iten   NaN     KEN     NaN        NaN
# 4  11    Kirui, Geoffrey   26   M  Keringet   NaN     KEN     NaN        NaN
#
#         5K  ...      25K      30K      35K      40K     Pace Proj Time  \
# 0  0:15:11  ...  1:16:23  1:32:01  1:47:16  2:01:45  0:04:53       NaN
# 1  0:15:10  ...  1:16:24  1:32:01  1:47:16  2:01:46  0:04:53       NaN
# 2  0:15:14  ...  1:16:24  1:32:01  1:47:16  2:01:45  0:04:54       NaN
# 3  0:15:14  ...  1:16:24  1:32:01  1:47:16  2:02:08  0:04:55       NaN
# 4  0:15:12  ...  1:16:23  1:32:01  1:47:16  2:01:57  0:04:56       NaN
#
#   Official Time Overall Gender Division
# 0       2:07:57       1      1        1
# 1       2:07:59       2      2        2
# 2       2:08:07       3      3        3
# 3       2:08:54       4      4        4
# 4       2:08:55       5      5        5
#
# [5 rows x 24 columns]

# %%
# Subset the dataframe to only the columns "Age", "M/F", split times (i.e. "5K, 10K", etc.), "Pace", and "Official Time". 
df = df[['Age', 'M/F', '5K', '10K', '15K', '20K', 'Half', '25K', '30K', '35K', '40K', 'Pace', 'Official Time']]
df.head()
# Out:
#    Age M/F       5K      10K      15K      20K     Half      25K      30K  \
# 0   30   M  0:15:11  0:30:21  0:45:48  1:01:16  1:04:29  1:16:23  1:32:01
# 1   29   M  0:15:10  0:30:22  0:45:46  1:01:16  1:04:30  1:16:24  1:32:01
# 2   34   M  0:15:14  0:30:22  0:45:47  1:01:17  1:04:31  1:16:24  1:32:01
# 3   32   M  0:15:14  0:30:24  0:45:47  1:01:16  1:04:31  1:16:24  1:32:01
# 4   26   M  0:15:12  0:30:21  0:45:46  1:01:15  1:04:28  1:16:23  1:32:01
#
#        35K      40K     Pace Official Time
# 0  1:47:16  2:01:45  0:04:53       2:07:57
# 1  1:47:16  2:01:46  0:04:53       2:07:59
# 2  1:47:16  2:01:45  0:04:54       2:08:07
# 3  1:47:16  2:02:08  0:04:55       2:08:54
# 4  1:47:16  2:01:57  0:04:56       2:08:55

# %%
# Convert the split times, "Pace", and "Official Time" to timedeltas using apply() and pandas.to_timedelta()
time_columns = ['5K', '10K', '15K', '20K', 'Half','25K', '30K', '35K', '40K', 'Pace', 'Official Time']
df[time_columns] = df[time_columns].apply(pd.to_timedelta)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/miniconda3/envs/class_env/lib/python3.10/site-packages/pandas/_libs/tslibs/timedeltas.pyx:354, in pandas._libs.tslibs.timedeltas.array_to_timedelta64()
#
# File /opt/miniconda3/envs/class_env/lib/python3.10/site-packages/pandas/_libs/tslibs/timedeltas.pyx:529, in pandas._libs.tslibs.timedeltas.parse_timedelta_string()
#
# ValueError: symbols w/o a number
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [6], in <module>
#       1 # Convert the split times, "Pace", and "Official Time" to timedeltas using apply() and pandas.to_timedelta()
#       2 time_columns = ['5K', '10K', '15K', '20K', 'Half','25K', '30K', '35K', '40K', 'Pace', 'Official Time']
# ----> 3 df[time_columns] = df[time_columns].apply(pd.to_timedelta)
#       4 df.head()
#
# File /opt/miniconda3/envs/class_env/lib/python3.10/site-packages/pandas/core/frame.py:8740, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8729 from pandas.core.apply import frame_apply
#    8731 op = frame_apply(
#    8732     self,
#    8733     func=func,
#    (...)
#    8738     kwargs=kwargs,
#    8739 )
# -> 8740 return op.apply()
#
# File /opt/miniconda3/envs/class_env/lib/python3.10/site-packages/pandas/core/apply.py:688, in FrameApply.apply(self)
#     685 elif self.raw:
#     686     return self.apply_raw()
# --> 688 return self.apply_standard()
#
# File /opt/miniconda3/envs/class_env/lib/python3.10/site-packages/pandas/core/apply.py:812, in FrameApply.apply_standard(self)
#     811 def apply_standard(self):
# --> 812     results, res_index = self.apply_series_generator()
#     814     # wrap results
#     815     return self.wrap_results(results, res_index)
#
# File /opt/miniconda3/envs/class_env/lib/python3.10/site-packages/pandas/core/apply.py:828, in FrameApply.apply_series_generator(self)
#     825 with option_context("mode.chained_assignment", None):
#     826     for i, v in enumerate(series_gen):
#     827         # ignore SettingWithCopy here in case the user mutates
# --> 828         results[i] = self.f(v)
#     829         if isinstance(results[i], ABCSeries):
#     830             # If we have a view on v, we need to make a copy because
#     831             #  series_generator will swap out the underlying data
#     832             results[i] = results[i].copy(deep=False)
#
# File /opt/miniconda3/envs/class_env/lib/python3.10/site-packages/pandas/core/tools/timedeltas.py:124, in to_timedelta(arg, unit, errors)
#     122     return arg
#     123 elif isinstance(arg, ABCSeries):
# --> 124     values = _convert_listlike(arg._values, unit=unit, errors=errors)
#     125     return arg._constructor(values, index=arg.index, name=arg.name)
#     126 elif isinstance(arg, ABCIndex):
#
# File /opt/miniconda3/envs/class_env/lib/python3.10/site-packages/pandas/core/tools/timedeltas.py:173, in _convert_listlike(arg, unit, errors, name)
#     170     arg = np.array(list(arg), dtype=object)
#     172 try:
# --> 173     td64arr = sequence_to_td64ns(arg, unit=unit, errors=errors, copy=False)[0]
#     174 except ValueError:
#     175     if errors == "ignore":
#
# File /opt/miniconda3/envs/class_env/lib/python3.10/site-packages/pandas/core/arrays/timedeltas.py:991, in sequence_to_td64ns(data, copy, unit, errors)
#     988 # Convert whatever we have into timedelta64[ns] dtype
#     989 if is_object_dtype(data.dtype) or is_string_dtype(data.dtype):
#     990     # no need to make a copy, need to convert if string-dtyped
# --> 991     data = objects_to_td64ns(data, unit=unit, errors=errors)
#     992     copy = False
#     994 elif is_integer_dtype(data.dtype):
#     995     # treat as multiples of the given unit
#
# File /opt/miniconda3/envs/class_env/lib/python3.10/site-packages/pandas/core/arrays/timedeltas.py:1100, in objects_to_td64ns(data, unit, errors)
#    1097 # coerce Index to np.ndarray, converting string-dtype if necessary
#    1098 values = np.array(data, dtype=np.object_, copy=False)
# -> 1100 result = array_to_timedelta64(values, unit=unit, errors=errors)
#    1101 return result.view("timedelta64[ns]")
#
# File /opt/miniconda3/envs/class_env/lib/python3.10/site-packages/pandas/_libs/tslibs/timedeltas.pyx:368, in pandas._libs.tslibs.timedeltas.array_to_timedelta64()
#
# File /opt/miniconda3/envs/class_env/lib/python3.10/site-packages/pandas/_libs/tslibs/timedeltas.pyx:359, in pandas._libs.tslibs.timedeltas.array_to_timedelta64()
#
# File /opt/miniconda3/envs/class_env/lib/python3.10/site-packages/pandas/_libs/tslibs/timedeltas.pyx:300, in pandas._libs.tslibs.timedeltas.convert_to_timedelta64()
#
# File /opt/miniconda3/envs/class_env/lib/python3.10/site-packages/pandas/_libs/tslibs/timedeltas.pyx:529, in pandas._libs.tslibs.timedeltas.parse_timedelta_string()
#
# ValueError: symbols w/o a number

# %%
# Convert timedeltas to seconds by applying the lambda function lambda x: x.dt.total_seconds()
df[time_columns] = df[time_columns].apply(lambda x: x.dt.total_seconds())
df.head()
# Out:
#    Age M/F     5K     10K     15K     20K    Half     25K     30K     35K  \
# 0   30   M  911.0  1821.0  2748.0  3676.0  3869.0  4583.0  5521.0  6436.0
# 1   29   M  910.0  1822.0  2746.0  3676.0  3870.0  4584.0  5521.0  6436.0
# 2   34   M  914.0  1822.0  2747.0  3677.0  3871.0  4584.0  5521.0  6436.0
# 3   32   M  914.0  1824.0  2747.0  3676.0  3871.0  4584.0  5521.0  6436.0
# 4   26   M  912.0  1821.0  2746.0  3675.0  3868.0  4583.0  5521.0  6436.0
#
#       40K   Pace  Official Time
# 0  7305.0  293.0         7677.0
# 1  7306.0  293.0         7679.0
# 2  7305.0  294.0         7687.0
# 3  7328.0  295.0         7734.0
# 4  7317.0  296.0         7735.0

# %%
# Subset df to only rows where the split values are non-zero
df = df[
    (df['5K'] != 0) & 
    (df['10K'] != 0) & 
    (df['15K'] != 0) & 
    (df['20K'] != 0) & 
    (df['Half'] != 0) & 
    (df['25K'] != 0) & 
    (df['30K'] != 0) & 
    (df['35K'] != 0) & 
    (df['40K'] != 0)
]

# A more concise method
#df = df[~(df == 0).any(axis=1)]

df.head()
# Out:
#    Age M/F       5K      10K      15K      20K     Half      25K      30K  \
# 0   30   M  0:15:11  0:30:21  0:45:48  1:01:16  1:04:29  1:16:23  1:32:01
# 1   29   M  0:15:10  0:30:22  0:45:46  1:01:16  1:04:30  1:16:24  1:32:01
# 2   34   M  0:15:14  0:30:22  0:45:47  1:01:17  1:04:31  1:16:24  1:32:01
# 3   32   M  0:15:14  0:30:24  0:45:47  1:01:16  1:04:31  1:16:24  1:32:01
# 4   26   M  0:15:12  0:30:21  0:45:46  1:01:15  1:04:28  1:16:23  1:32:01
#
#        35K      40K     Pace Official Time
# 0  1:47:16  2:01:45  0:04:53       2:07:57
# 1  1:47:16  2:01:46  0:04:53       2:07:59
# 2  1:47:16  2:01:45  0:04:54       2:08:07
# 3  1:47:16  2:02:08  0:04:55       2:08:54
# 4  1:47:16  2:01:57  0:04:56       2:08:55

# %%
# Use LabelEncoder to convert 'M/F' into integer labels
df['M/F'] = LabelEncoder().fit_transform(df['M/F'])

# Equivalently, the encoder can be created and applied in two steps
# encoder = LabelEncoder().fit(df['M/F'])
# df['M/F'] = encoder.transform(df['M/F'])

df.head()
# Out:
#    Age  M/F       5K      10K      15K      20K     Half      25K      30K  \
# 0   30    1  0:15:11  0:30:21  0:45:48  1:01:16  1:04:29  1:16:23  1:32:01
# 1   29    1  0:15:10  0:30:22  0:45:46  1:01:16  1:04:30  1:16:24  1:32:01
# 2   34    1  0:15:14  0:30:22  0:45:47  1:01:17  1:04:31  1:16:24  1:32:01
# 3   32    1  0:15:14  0:30:24  0:45:47  1:01:16  1:04:31  1:16:24  1:32:01
# 4   26    1  0:15:12  0:30:21  0:45:46  1:01:15  1:04:28  1:16:23  1:32:01
#
#        35K      40K     Pace Official Time
# 0  1:47:16  2:01:45  0:04:53       2:07:57
# 1  1:47:16  2:01:46  0:04:53       2:07:59
# 2  1:47:16  2:01:45  0:04:54       2:08:07
# 3  1:47:16  2:02:08  0:04:55       2:08:54
# 4  1:47:16  2:01:57  0:04:56       2:08:55

# %%
# Convert 'Age' to a numeric value
df['Age'] = pd.to_numeric(df['Age'])

# %%
# 'Pace' should be perfectly correlated with 'Official Time', so we'll remove it from our X data (but keep it for analysis)
# Plot a scatter plot of 'Pace' against 'Official Time'
df.plot(kind='scatter', x='Pace', y='Official Time')
# Out:
# <AxesSubplot:xlabel='Pace', ylabel='Official Time'>

# %%
# Create a training set 'X' with every column except 'Pace'
X = df.drop('Pace', axis=1)

# Alternatively, select all the columns to keep
#X = df[['Age', 'M/F','5K','10K','15K','20K','25K','30K','35K','40K','Half','Official Time']]

# %%
# Scale the dataset using MinMaxScaler()
X_scaled = MinMaxScaler().fit_transform(X)
X_scaled
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [12], in <module>
#       1 # Scale the dataset using MinMaxScaler()
# ----> 2 X_scaled = MinMaxScaler().fit_transform(X)
#       3 X_scaled
#
# File /opt/miniconda3/envs/class_env/lib/python3.10/site-packages/sklearn/base.py:852, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     848 # non-optimized default implementation; override when a better
#     849 # method is possible for a given clustering algorithm
#     850 if y is None:
#     851     # fit method of arity 1 (unsupervised transformation)
# --> 852     return self.fit(X, **fit_params).transform(X)
#     853 else:
#     854     # fit method of arity 2 (supervised transformation)
#     855     return self.fit(X, y, **fit_params).transform(X)
#
# File /opt/miniconda3/envs/class_env/lib/python3.10/site-packages/sklearn/preprocessing/_data.py:416, in MinMaxScaler.fit(self, X, y)
#     414 # Reset internal state before fitting
#     415 self._reset()
# --> 416 return self.partial_fit(X, y)
#
# File /opt/miniconda3/envs/class_env/lib/python3.10/site-packages/sklearn/preprocessing/_data.py:453, in MinMaxScaler.partial_fit(self, X, y)
#     447     raise TypeError(
#     448         "MinMaxScaler does not support sparse input. "
#     449         "Consider using MaxAbsScaler instead."
#     450     )
#     452 first_pass = not hasattr(self, "n_samples_seen_")
# --> 453 X = self._validate_data(
#     454     X,
#     455     reset=first_pass,
#     456     estimator=self,
#     457     dtype=FLOAT_DTYPES,
#     458     force_all_finite="allow-nan",
#     459 )
#     461 data_min = np.nanmin(X, axis=0)
#     462 data_max = np.nanmax(X, axis=0)
#
# File /opt/miniconda3/envs/class_env/lib/python3.10/site-packages/sklearn/base.py:566, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     564     raise ValueError("Validation should be done on X, y or both.")
#     565 elif not no_val_X and no_val_y:
# --> 566     X = check_array(X, **check_params)
#     567     out = X
#     568 elif no_val_X and not no_val_y:
#
# File /opt/miniconda3/envs/class_env/lib/python3.10/site-packages/sklearn/utils/validation.py:746, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     744         array = array.astype(dtype, casting="unsafe", copy=False)
#     745     else:
# --> 746         array = np.asarray(array, order=order, dtype=dtype)
#     747 except ComplexWarning as complex_warning:
#     748     raise ValueError(
#     749         "Complex data not supported\n{}\n".format(array)
#     750     ) from complex_warning
#
# File /opt/miniconda3/envs/class_env/lib/python3.10/site-packages/pandas/core/generic.py:1993, in NDFrame.__array__(self, dtype)
#    1992 def __array__(self, dtype: NpDtype | None = None) -> np.ndarray:
# -> 1993     return np.asarray(self._values, dtype=dtype)
#
# ValueError: could not convert string to float: '0:15:11'
